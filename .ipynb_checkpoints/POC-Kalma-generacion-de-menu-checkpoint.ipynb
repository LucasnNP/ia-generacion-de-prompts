# %% [markdown]
# # Proyecto – Inteligencia Artificial: Generación de Prompts
# **Alumno:** Lucas Prat
# **Comisión:** [86185]
# **Nombre del Proyecto:** Kalma – Generación de menús y recursos visuales con IA

# %% [markdown]
# ## Introducción
# El presente proyecto se desarrolla en el marco del curso **Inteligencia Artificial: Generación de Prompts**.
# El objetivo es resolver una problemática real: el tiempo que los nutricionistas dedican a la creación de **menús personalizados** y de **materiales visuales atractivos** para sus pacientes.
#
# Esto se conecta con **Kalma**, una plataforma digital en desarrollo para nutricionistas.
#
# Para la solución utilizaremos:
# - **Gemini** como modelo de Texto → Texto.
# - **Stable Diffusion** como plataforma de Texto → Imagen.
#
# Se aplicará la técnica de **Fast Prompting**, optimizando la generación de menús y prompts visuales en un solo flujo.

# %% [markdown]
# ## Presentación del problema
# En la práctica clínica de los nutricionistas, una de las tareas más demandantes y repetitivas es la
# creación de menús personalizados para sus pacientes. Cada menú debe adaptarse a variables
# como: edad, peso, condición de salud, cultura alimentaria, preferencias personales, objetivos
# nutricionales y restricciones económicas.
#
# Actualmente, muchos profesionales dedican tiempo excesivo a esta tarea, lo que reduce las horas
# disponibles para la atención personalizada y el acompañamiento del paciente.
#
# Además, los pacientes suelen recibir estos planes en formato texto, lo que dificulta la comprensión o
# la motivación para seguirlos. La falta de recursos visuales y de una comunicación clara afecta la
# adherencia a los tratamientos.
#
# Por estas razones, existe una necesidad concreta de herramientas que automaticen la generación de
# menús, hagan más eficiente el trabajo del nutricionista y ofrezcan una experiencia más clara,
# atractiva y motivadora para el paciente.

# %% [markdown]
# ## Desarrollo de la propuesta de solución
# La propuesta es integrar en Kalma (plataforma digital para nutricionistas) un sistema basado en
# generación de prompts, que permita:
#
# 1. Generación de menús personalizados (texto-texto):
# A partir de los datos del paciente, un modelo de IA podrá generar un menú adaptado:
# - Datos clínicos: edad, peso, patologías, objetivos (ej. bajar colesterol).
# - Contexto cultural: comidas típicas de la región.
# - Preferencias personales: vegetarianismo, intolerancias, presupuesto disponible.
# El nutricionista recibe una propuesta inicial que puede ajustar antes de entregar al paciente.
#
# 2. Representación visual de menús (texto-imagen):
#
# Generar ilustraciones o imágenes de los platos sugeridos, para que el paciente pueda visualizar
# cómo luce una porción balanceada. Crear infografías sencillas (ej. plato saludable dividido en
# proteínas, carbohidratos y vegetales).

# %% [markdown]
# ## Objetivos
# - Generar menús personalizados de forma automática y contextualizada.
# - Crear prompts optimizados para generar imágenes educativas en Nightcafe.
# - Implementar la técnica de **Fast Prompting** para reducir la cantidad de consultas necesarias.
# - Validar la viabilidad técnica de la propuesta en un flujo simple y replicable.

# %% [markdown]
# ## Metodología
#
# El proyecto se llevará a cabo en un entorno de trabajo basado en **Jupyter Notebook**, alternando celdas de Markdown (para la explicación conceptual) con celdas de código en Python (para la implementación práctica). La metodología se estructura en cinco etapas principales:
#
# 1. **Definición del problema y contexto**
#    Se presenta la problemática de los nutricionistas que requieren generar menús personalizados y materiales visuales educativos para sus pacientes. Esta etapa incluye la justificación de la relevancia del problema y la conexión con la plataforma Kalma.
#
# 2. **Diseño y experimentación de prompts en Gemini (Texto → Texto)**
#    Se diseñarán distintos tipos de prompts para la generación de menús:
#    - **Zero-shot prompting**: se da únicamente la instrucción, sin ejemplos previos.
#    - **One-shot prompting**: se incluye un ejemplo de menú como guía.
#    - **Few-shot prompting**: se incluyen varios ejemplos de menús como referencia.
#
#    Esto permitirá comparar qué metodología produce resultados más relevantes y consistentes para el caso de uso de nutricionistas.
#
# 3. **Generación de imágenes con Stable Diffusion (Texto → Imagen)**
#    A partir de los menús generados en Gemini, se construyen prompts optimizados en inglés y se utilizan con el modelo **Stable Diffusion**, integrado mediante la librería **diffusers**. Esto permitirá producir representaciones visuales **realistas, educativas y coherentes** con los menús generados.
#
# 4. **Implementación de Fast Prompting**
#    Se aplica la técnica de **Fast Prompting**, integrando en un único prompt tanto la generación del menú como la creación de los prompts visuales. De este modo se reduce la cantidad de consultas al modelo, optimizando tiempos y recursos.
#
#    Finalmente, se validan los resultados comparando:
#    - Zero-shot, One-shot y Few-shot prompting.
#    - Prompts separados vs. Fast Prompting.
#    Esto permitirá determinar la configuración más eficiente y precisa para el problema planteado.
#
# ### Justificación de la metodología
# Este enfoque permite:
# - **Evaluación comparativa**: probar distintas metodologías de prompting asegura elegir la más adecuada para el caso de uso.
# - **Replicabilidad**: cualquier usuario puede ejecutar la notebook y obtener resultados personalizados.
# - **Optimización**: el uso de Fast Prompting minimiza la cantidad de consultas al modelo, reduciendo costos y tiempos de procesamiento.

# %% [markdown]
# ## Comparativa
#
# Para realizar la comparativa primero se va importar todas las dependencias necesarias.

# %%
import google.generativeai as genai

# Configuración de Gemini
genai.configure(api_key="TU_API_KEY_GEMINI")
model = genai.GenerativeModel("gemini-1.5-flash")

# %%
# Método Zero-shot prompting

prompt_zero = """
Eres un nutricionista especializado en planes personalizados.
Genera un menú diario para un paciente adulto de 40 años con hipertensión,
que vive en Argentina. Incluye desayuno, almuerzo, merienda, cena y dos colaciones.
"""

response_zero = model.generate_content(prompt_zero)
print("\n--- Zero-shot ---\n")
print(response_zero.text)
# Out:
# --- Zero-shot ---
#
# ## Menú Diario para paciente adulto con Hipertensión (40 años - Argentina)
#
# Este menú se enfoca en una dieta rica en frutas, verduras, cereales integrales y proteínas magras, baja en sodio, grasas saturadas y colesterol,  adecuada para un adulto de 40 años con hipertensión.  Es importante recordar que este es un ejemplo y  se debe ajustar a las necesidades y preferencias individuales del paciente, consultando siempre con su médico y/o nutricionista.  Las porciones deben ajustarse al gasto calórico individual.
#
# **Desayuno (aprox. 350 calorías):**
#
# * **Avena con frutas y semillas:** 1/2 taza de avena integral cocida con 1 taza de leche descremada o bebida vegetal sin azúcar (soja, almendras).  Agregar 1/4 taza de frutos rojos (frutillas, arándanos) y 1 cucharadita de semillas de chía o lino.  Se puede endulzar con una cucharadita de miel o stevia al gusto.
#
# **Colación 1 (aprox. 100 calorías):**
#
# * **Fruta fresca:** 1 manzana mediana con cáscara o 1 pera o 1 naranja.
#
# **Almuerzo (aprox. 500 calorías):**
#
# * **Milanesa de pollo a la plancha con ensalada mixta:** 1 milanesa de pechuga de pollo (sin piel) a la plancha. Acompañar con una ensalada mixta grande (lechuga, tomate, pepino, zanahoria rallada) aderezada con jugo de limón, aceite de oliva y orégano.  Evitar agregar sal.
#
# **Colación 2 (aprox. 150 calorías):**
#
# * **Yogur descremado con nueces:** 1 pote de yogur descremado (natural, sin azúcar) con 5 nueces.
#
# **Cena (aprox. 400 calorías):**
#
# * **Sopa de verduras con 1 porción de pescado al horno:** Sopa de verduras (zapallo, cebolla, acelga, zanahoria) hecha con caldo desgrasado de verduras (sin cubos saborizados).  Acompañar con 1 porción (100-120 gr) de pescado blanco al horno (merluza, lenguado, etc.)  con  hierbas frescas (perejil, cilantro).  Evitar sal.
#
#
# **Recomendaciones Adicionales:**
#
# * **Hidratación:** Beber al menos 2 litros de agua por día.  Se puede incluir infusiones de hierbas (sin azúcar).
# * **Reducción de sodio:** Evitar el uso de sal de mesa y optar por especias y hierbas aromáticas para condimentar las comidas.  Leer las etiquetas de los alimentos procesados para verificar el contenido de sodio.
# * **Control de porciones:** Es fundamental controlar el tamaño de las porciones para mantener un peso saludable.
# * **Actividad física:** La actividad física regular es esencial para controlar la hipertensión. Se recomienda al menos 30 minutos de ejercicio moderado la mayoría de los días de la semana.
# * **Alimentos a evitar o limitar:** Carnes rojas, embutidos, alimentos procesados, enlatados,  frituras,  dulces, bebidas azucaradas,  alcohol.
#
#
# **Nota:** Este menú es un ejemplo y debe ser adaptado a las necesidades individuales del paciente.  Es fundamental consultar con un nutricionista registrado para obtener un plan nutricional personalizado que considere los antecedentes médicos, preferencias alimentarias y estilo de vida del paciente. La información proporcionada no sustituye la consulta médica profesional.

# %%
# Método One-shot prompting

prompt_one = """
Eres un nutricionista especializado en planes personalizados.
Aquí tienes un ejemplo de menú:

Ejemplo:
Desayuno: Yogur natural con avena y rodajas de manzana.
Almuerzo: Pollo grillado con ensalada de hojas verdes y tomate.
Merienda: Infusión con tostadas integrales.
Cena: Pescado al horno con puré de zapallo.

Ahora genera un menú diario para un paciente adulto de 40 años con hipertensión,
que vive en Argentina. Incluye desayuno, almuerzo, merienda, cena y dos colaciones.
"""

response_one = model.generate_content(prompt_one)
print("\n--- One-shot ---\n")
print(response_one.text)
# Out:
# --- One-shot ---
#
# Menú diario para paciente adulto de 40 años con hipertensión (Argentina)
#
# Este menú se enfoca en una dieta rica en potasio, magnesio y fibra, baja en sodio, grasas saturadas y colesterol, adecuada para controlar la hipertensión.  Recuerda que este es un ejemplo y se debe ajustar a las necesidades individuales y preferencias del paciente después de una consulta nutricional completa.  La cantidad de porciones se debe ajustar según el gasto energético del individuo.
#
# **Desayuno (7:00 AM):**
#
# * Avena instantánea (1/2 taza) cocida con leche descremada (1 taza) y  un puñado de frutos rojos (frutillas, arándanos, frambuesas).  Se puede agregar una cucharadita de semillas de chía.
# *  Infusion de hierbas (manzanilla, tilo).
#
#
# **Colacion 1 (10:00 AM):**
#
# *  Una manzana mediana con 2 cucharadas de queso crema descremado (o yogur descremado natural).
#
# **Almuerzo (13:00 PM):**
#
# *  Milanesa de soja a la napolitana (con tomate, ajo y orégano,  mínimo de sal).  Servida con puré de calabaza o batata (sin crema de leche ni manteca).  Opción:  Sopa de verduras (zapallo, zanahoria, cebolla, puerro) con una porción pequeña de pan integral.
#
# **Colacion 2 (16:00 PM):**
#
# *  Un puñado de almendras (aproximadamente 20 unidades)  o  un yogur descremado natural con 1 cucharada de semillas de lino.
#
# **Cena (20:00 PM):**
#
# *  Brochetas de pescado blanco (merluza, lenguado) a la plancha con verduras grilladas (pimientos, zucchini, cebolla).  Se puede utilizar un aderezo ligero de limón y hierbas frescas.
#
# **Consideraciones importantes:**
#
# * **Control del sodio:** Utilizar mínimamente sal en la preparación de los alimentos.  Utilizar especias y hierbas aromáticas para sazonar.  Evitar alimentos procesados, envasados y precocidos, que suelen ser altos en sodio.
# * **Hidratación:**  Consumir abundante agua a lo largo del día (al menos 2 litros).
# * **Potasio:** Incluir alimentos ricos en potasio como las bananas, las papas (con cáscara), los tomates, las espinacas y los frutos secos (con moderación).
# * **Magnesio:**  Incluir alimentos ricos en magnesio como las almendras, las semillas de chía y las legumbres (ej: lentejas).
# * **Grasas saludables:** Priorizar el consumo de grasas saludables como las del aceite de oliva, las palta y los frutos secos (con moderación).
# * **Limitar:**  Carnes rojas, embutidos, fiambres, productos de pastelería, bebidas azucaradas, frituras.
#
# **Importante:** Este menú es una sugerencia general. Se recomienda consultar con un nutricionista o médico para un plan personalizado que se ajuste a las necesidades específicas del paciente, incluyendo posibles restricciones o alergias alimentarias, así como  evaluar la necesidad de suplementos.  La hipertensión requiere un enfoque multidisciplinario que incluya  medicación,  cambio de hábitos de vida y control regular.

# %%
# Método Few-shot prompting

prompt_few = """
Eres un nutricionista especializado en planes personalizados.

Ejemplo 1:
Desayuno: Licuado de banana y leche descremada.
Almuerzo: Ensalada de lentejas con vegetales.
Merienda: Yogur con frutas rojas.
Cena: Filete de pollo con calabaza asada.

Ejemplo 2:
Desayuno: Infusión con tostadas integrales y queso bajo en sodio.
Almuerzo: Pollo grillado con ensalada de rúcula y tomate.
Merienda: Licuado de frutilla y leche descremada.
Cena: Merluza al vapor con arroz integral.

Ahora genera un menú diario para un paciente adulto de 40 años con hipertensión,
que vive en Argentina. Incluye desayuno, almuerzo, merienda, cena y dos colaciones.
"""

response_few = model.generate_content(prompt_few)
print("\n--- Few-shot ---\n")
print(response_few.text)
# Out:
# --- Few-shot ---
#
# ## Menú diario para paciente adulto de 40 años con hipertensión (Argentina)
#
# Este menú está diseñado para un adulto de 40 años con hipertensión, teniendo en cuenta la disponibilidad de alimentos en Argentina y enfocándose en una dieta baja en sodio, rica en potasio, fibra y baja en grasas saturadas.  Es importante consultar con un médico o nutricionista antes de realizar cambios significativos en la dieta.  Las porciones deben ajustarse a las necesidades calóricas individuales.
#
# **Desayuno (8:00 AM):**
#
# * **Avena con leche descremada (200ml) y frutas de estación:** 1/2 taza de avena arrollada, 200ml de leche descremada, 1/2 taza de frutas de estación (ej: frutillas, naranjas, kiwi - ricas en potasio).  Se puede agregar una cucharadita de semillas de chía o lino para aumentar la fibra.
#
# **Colación 1 (10:30 AM):**
#
# * **Manzana con 2 almendras:**  La manzana aporta fibra y potasio, mientras que las almendras brindan grasas saludables.
#
#
# **Almuerzo (13:00 PM):**
#
# * **Lomo de merluza al horno con puré de calabaza y zapallitos:**  150 gr de merluza al horno (cocinada con hierbas y especias, sin sal agregada), 1 taza de puré de calabaza (preparado sin crema ni manteca), 1/2 taza de zapallitos grillados.
#
#
# **Colación 2 (16:00 PM):**
#
# * **Yogur descremado con 1/4 taza de frutos rojos:** El yogur descremado aporta calcio y proteínas, mientras que los frutos rojos son ricos en antioxidantes.
#
#
# **Cena (20:00 PM):**
#
# * **Sopa de verduras con 1 rebanada de pan integral:**  Sopa de verduras casera (ej: zapallo, acelga, cebolla, zanahoria) preparada sin sal agregada o con muy poca, 1 rebanada de pan integral.
#
#
# **Recomendaciones adicionales:**
#
# * **Control de sodio:** Evitar el consumo excesivo de sal, embutidos, fiambres, snacks procesados y alimentos enlatados. Utilizar hierbas y especias para condimentar las comidas.
# * **Aumentar el consumo de potasio:** Incluir regularmente frutas y verduras ricas en potasio como bananas, naranjas, papas (con cáscara), tomates, espinacas.
# * **Hidratación:** Beber abundante agua a lo largo del día (al menos 2 litros).
# * **Actividad física:** Realizar ejercicio físico regularmente, según las recomendaciones médicas.
#
#
# **Nota:** Este menú es un ejemplo y puede ser adaptado a las preferencias y necesidades individuales del paciente. Es fundamental consultar con un profesional de la salud para un plan nutricional personalizado y seguro.  La información proporcionada no sustituye la consulta médica.

# %% [markdown]
# ## Herramientas y Tecnologías
#
# En este proyecto se utilizan las siguientes herramientas:
#
# - **Gemini (Texto → Texto)**: modelo de lenguaje de Google para generar menús personalizados y prompts de imágenes.
# - **Stable Diffusion (Texto → Imagen)**: plataforma para transformar los prompts generados en representaciones visuales educativas de los platos.
#
# ### Técnicas de prompting utilizadas
#
# 1. **Zero-shot prompting**
#    Útil para obtener resultados rápidos sin ejemplos. Permite evaluar la capacidad base del modelo.
#    *Limitación*: la consistencia no siempre es alta.
#
# 2. **One-shot prompting**
#    Se incluye un ejemplo de referencia, lo cual ayuda a orientar mejor el formato de salida.
#    *Ventaja*: resultados más consistentes y alineados con la estructura deseada.
#
# 3. **Few-shot prompting**
#    Al dar múltiples ejemplos, el modelo entiende mejor el estilo esperado.
#    *Ventaja*: mayor control sobre el resultado.
#    *Limitación*: mayor extensión en el prompt, lo que puede aumentar costos.
#
# 4. **Fast Prompting**
#    Se integra en un único prompt la generación de menús y de los prompts para Stable Diffusion.
#    *Ventaja*: reduce la cantidad de consultas, optimiza tiempo y recursos.
#
# ### Justificación
#
# Se utilizan estas técnicas en conjunto para:
# - Evaluar cuál entrega resultados más relevantes y consistentes para el caso de uso.
# - Optimizar la generación de menús y materiales visuales en un único flujo.
# - Asegurar la viabilidad del proyecto con la menor cantidad de consultas posibles.

# %% [markdown]
# ## Implementación
#
# A continuación, se presenta la implementación de un prompt que aplica **Fast Prompting**, unificando en una única consulta la generación de menús personalizados y de los prompts de imágenes para Stable Difussion.

# %%
#Uso de Fast prompting

fast_prompt = """
Eres un nutricionista.
1. Genera un menú diario para un adulto de 40 años con hipertensión, residente en Argentina.
2. Luego, para cada comida del menú, genera un prompt en inglés para Stable Disfussion,
   en estilo realista, educativo y atractivo. tené en cuenta no exceder los tokens de la versión gratuita.
"""

response_fast = model.generate_content(fast_prompt)
print("\n--- Implementación con Fast Prompting ---\n")
print(response_fast.text)
# Out:
# --- Implementación con Fast Prompting ---
#
# ## Menú Diario para Adulto de 40 Años con Hipertensión (Argentina)
#
# Este menú se enfoca en reducir la ingesta de sodio, grasas saturadas y colesterol, mientras se asegura un aporte adecuado de potasio, magnesio y fibra, importantes para el control de la presión arterial.  Recuerda consultar con tu médico o nutricionista antes de realizar cambios significativos en tu dieta.
#
# **Desayuno (7:00 AM):**
#
# * Avena con leche descremada (200ml) y frutos rojos (1 taza)
# * 1 rebanada de pan integral tostado con palta (aguacate)
#
# **Almuerzo (13:00 PM):**
#
# * Sopa de verduras (zapallo, zanahoria, cebolla, acelga) con un puñado de quinoa.
# * Pechuga de pollo a la plancha (150g)
# * Ensalada de rúcula, tomate y pepino con 1 cucharada de aceite de oliva.
#
# **Merienda (16:00 PM):**
#
# * Yogurt descremado (150g) con  frutos secos (almendras, nueces, sin sal) (un puñado)
#
# **Cena (20:00 PM):**
#
# * Brocheta de pescado blanco (merluza o similar) con verduras asadas (pimientos, zucchini, cebolla)
# * 1 porción pequeña de arroz integral.
#
#
# ## Prompts para Stable Diffusion:
#
# Aquí hay prompts para Stable Diffusion, intentando mantenerlos dentro del límite de tokens y  enfocados en un estilo realista, educativo y atractivo. Recuerda que los resultados pueden variar dependiendo de la versión del modelo y los parámetros utilizados.
#
# **Desayuno:**
#
# >`A photorealistic image of a healthy breakfast for hypertension: oatmeal with skim milk and fresh berries in a rustic bowl, next to a slice of whole-wheat toast with mashed avocado.  The scene is bright and inviting, showcasing the natural colors of the food. Style: healthy eating photography.`
#
#
# **Almuerzo:**
#
# >`A realistic and appetizing image of a hypertension-friendly lunch: a bowl of vibrant vegetable soup with quinoa, alongside grilled chicken breast and a fresh salad of arugula, tomato, and cucumber with a drizzle of olive oil. The photo should highlight the freshness and nutritional value of the ingredients. Style: healthy food photography, magazine style.`
#
#
# **Merienda:**
#
# >`A close-up, realistic image of a healthy snack for hypertension: a cup of plain nonfat yogurt topped with a small handful of unsalted almonds and walnuts.  The focus is on the creamy texture and natural ingredients. Style: food photography, clean and minimalist.`
#
#
# **Cena:**
#
# >`A realistic and elegant image of a healthy dinner for hypertension: a grilled white fish (merluza/hake) skewer with roasted bell peppers, zucchini, and onions, served with a small portion of brown rice. The lighting should be warm and inviting, highlighting the freshness of the ingredients. Style: healthy recipe photography, restaurant-style.`
#
#
# Recuerda que estos son solo ejemplos. Puedes ajustar los prompts añadiendo detalles o modificando el estilo según tus preferencias y la capacidad del modelo. Experimentar es clave para obtener los mejores resultados con Stable Diffusion.

# %%
# se muestra el resultado de generar la imágen sólo con el ejemplo del almuerzo por ejemplo
# dependencias
from diffusers import StableDiffusionPipeline
import torch
import IPython.display as display

# Cargar el modelo desde Hugging Face (gratuito, pero requiere token)
model_id = "stabilityai/stable-diffusion-2"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float32)
pipe = pipe.to("cuda" if torch.cuda.is_available() else "cpu")

# Prompt generado por Gemini
prompt = "A realistic and appetizing image of a hypertension-friendly lunch: a bowl of vibrant vegetable soup with quinoa, alongside grilled chicken breast and a fresh salad of arugula, tomato, and cucumber with a drizzle of olive oil. The photo should highlight the freshness and nutritional value of the ingredients. Style: healthy food photography, magazine style."

# Generar imagen

image = pipe(prompt).images[0]

# Mostrar en Notebook
display.display(image)
# Out:
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=768x768>

# %% [markdown]
# ## comentarios finales
# En el primer intento al correr el código para generar la imagén, se mostró un aviso de que se excedio el índice de Tokens, lo que resultó en que se cortó las últimas líneas del prompt, por lo que la imágen resultó en errores de indexación. Luego, se iteró en el fast prompting indicandole qué el prompt que arrojara no excediera el límite de tokens permitidos en la versión gratuita de Stable Diffusion a fin de conseguir el prompt adecuado, resultando en la imagen que se meustra arriba.
#
# - Primer prompt recibido: "A realistic and appetizing photo of a light lunch: grilled chicken breast salad with lettuce, tomato, cucumber, and shredded carrots, dressed with a light lemon-olive oil vinaigrette.  Served alongside a portion of brown rice.  The photo should showcase fresh ingredients and healthy portion sizes, ideal for a dietary guide for hypertension. Style: realistic, natural lighting, high resolution. Emphasis on fresh and healthy ingredients."
# - Prompt definitivo: "A realistic and appetizing image of a hypertension-friendly lunch: a bowl of vibrant vegetable soup with quinoa, alongside grilled chicken breast and a fresh salad of arugula, tomato, and cucumber with a drizzle of olive oil. The photo should highlight the freshness and nutritional value of the ingredients. Style: healthy food photography, magazine style."
